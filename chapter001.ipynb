# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sklearn.linear_model

# %%
# load_data
oecd_bli = pd.read_csv('BLI_02092021145356851.csv', thousands=',')
gdp_per_capita = pd.read_csv('WEOApr2021all.xls', thousands=',', delimiter='\t', encoding='latin1', na_values=None)

# %%
oecd_bli[oecd_bli['Country']=='Turkey'][:5]
# Out:
#     LOCATION Country INDICATOR                 Indicator MEASURE Measure  \
# 25       TUR  Turkey   JE_LMIS  Labour market insecurity       L   Value
# 58       TUR  Turkey   JE_LMIS  Labour market insecurity       L   Value
# 90       TUR  Turkey   JE_LMIS  Labour market insecurity       L   Value
# 122      TUR  Turkey   JE_LMIS  Labour market insecurity       L   Value
# 154      TUR  Turkey   JE_LMIS  Labour market insecurity       L   Value
#
#     INEQUALITY Inequality Unit Code        Unit  PowerCode Code PowerCode  \
# 25         TOT      Total        PC  Percentage               0     Units
# 58          MN        Men        PC  Percentage               0     Units
# 90         WMN      Women        PC  Percentage               0     Units
# 122        HGH       High        PC  Percentage               0     Units
# 154         LW        Low        PC  Percentage               0     Units
#
#      Reference Period Code  Reference Period  Value  Flag Codes  Flags
# ...

# %%
gdp_per_capita[gdp_per_capita['Country'] == 'Turkey'][:5]
# Out:
#      WEO Country Code  ISO WEO Subject Code Country  \
# 8010              186  TUR           NGDP_R  Turkey
# 8011              186  TUR        NGDP_RPCH  Turkey
# 8012              186  TUR             NGDP  Turkey
# 8013              186  TUR            NGDPD  Turkey
# 8014              186  TUR           PPPGDP  Turkey
#
#                            Subject Descriptor  \
# 8010  Gross domestic product, constant prices
# 8011  Gross domestic product, constant prices
# 8012   Gross domestic product, current prices
# 8013   Gross domestic product, current prices
# 8014   Gross domestic product, current prices
#
#                                           Subject Notes  \
# 8010  Expressed in billions of national currency uni...
# 8011  Annual percentages of constant price GDP are y...
# 8012  Expressed in billions of national currency uni...
# 8013  Values are based upon GDP in national currency...
# 8014  These data form the basis for the country weig...
#
# ...

# %%
# prepare the data
country_stats = prepare_c
